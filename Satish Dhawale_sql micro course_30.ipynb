# %%
import pandas as pd

# %%
df_books=pd.read_csv(r"D:\Computer_learning\SQL\Satish Dhawale_ytb\Lessons\Project_lesson_30\drive-download-20250519T041700Z-1-001\Books.csv")
df_customers=pd.read_csv(r"D:\Computer_learning\SQL\Satish Dhawale_ytb\Lessons\Project_lesson_30\drive-download-20250519T041700Z-1-001\Customers.csv")
df_orders=pd.read_csv(r"D:\Computer_learning\SQL\Satish Dhawale_ytb\Lessons\Project_lesson_30\drive-download-20250519T041700Z-1-001\Orders.csv")

# %%
df_books.head(2)
# Out:
#    Book_ID                                  Title        Author      Genre  \
# 0        1        Configurable modular throughput  Joseph Crane  Biography
# 1        2  Persevering reciprocal knowledge user   Mario Moore    Fantasy
#
#    Published_Year  Price  Stock
# 0            1949  21.34    100
# 1            1971  35.80     19

# %%
#Retrieve all books in the "Fiction" genre
fiction_books=df_books[df_books["Genre"]=='Fiction']
print (fiction_books)
# Out:
#      Book_ID                                          Title  \
# 3          4                    Customizable 24hour product
# 21        22             Multi-layered optimizing migration
# 27        28                      Expanded analyzing portal
# 28        29        Quality-focused multi-tasking challenge
# 30        31        Implemented encompassing conglomeration
# 38        39         Optimized national process improvement
# 39        40                    Adaptive didactic interface
# 46        47  Reverse-engineered directional conglomeration
# 61        62           Re-contextualized real-time strategy
# 62        63                   Polarized heuristic database
# 99       100        Synchronized client-server service-desk
# 115      116            Multi-tiered foreground contingency
# 124      125         Public-key analyzing Graphic Interface
# 129      130  Realigned context-sensitive pricing structure
# 133      134       Polarized bandwidth-monitored throughput
# ...

# %%
# Find books published after the year 1950
books_after_1950=df_books[df_books["Published_Year"]>1950]
books_after_1950.to_excel("Books after 1950.xlsx")

# %%
# List all customers from the Canada
df_customers[df_customers["Country"]=="Canada"]
# Out:
#      Customer_ID             Name                    Email       Phone  \
# 37            38  Nicholas Harris  christine93@perkins.com  1234567928
# 414          415    James Ramirez        robert54@hall.com  1234568305
# 467          468       David Hart  stokesrebecca@gmail.com  1234568358
#
#              City Country
# 37      Davistown  Canada
# 414   Maxwelltown  Canada
# 467  Thompsonfurt  Canada

# %%
df_orders.head(2)
# Out:
#    Order_ID  Customer_ID  Book_ID  Order_Date  Quantity  Total_Amount
# 0         1           84      169  2023-05-26         8        188.56
# 1         2          137      301  2023-01-23        10        216.60

# %%
# Show orders placed in November 2023
df_orders["Order_Date"]=pd.to_datetime(df_orders["Order_Date"])

# %%
df_orders.dtypes
# Out:
# Order_ID                 int64
# Customer_ID              int64
# Book_ID                  int64
# Order_Date      datetime64[ns]
# Quantity                 int64
# Total_Amount           float64
# dtype: object

# %%
df_orders[(df_orders["Order_Date"].dt.month==11) & (df_orders["Order_Date"].dt.year==2023)]
# Out:
#      Order_ID  Customer_ID  Book_ID Order_Date  Quantity  Total_Amount
# 3           4          433      343 2023-11-25         7        301.21
# 18         19          496       60 2023-11-17         9        316.26
# 74         75          291      375 2023-11-30         5        170.75
# 131       132          469      333 2023-11-22         7        194.32
# 136       137          474      471 2023-11-25         8        363.04
# 162       163          207      384 2023-11-23         3        101.76
# 181       182          129      293 2023-11-01         7        125.51
# 199       200          313      303 2023-11-23         1          6.57
# 212       213          325      447 2023-11-17         7        253.75
# 230       231           22      384 2023-11-11         1         33.92
# 244       245          386       97 2023-11-01         9        411.66
# 251       252          405      387 2023-11-15         5        237.10
# ...

# %%
#Retrieve the total stock of books available
df_books["Stock"].sum()
# Out:
# 25056

# %%
#Find the details of the most expensive book
df_books.sort_values(by="Price", ascending=False).head(1)
# Out:
#      Book_ID                                  Title        Author    Genre  \
# 339      340  Proactive system-worthy orchestration  Robert Scott  Mystery
#
#      Published_Year  Price  Stock
# 339            1907  49.98     88

# %%
df_customers.head(2)
# Out:
#    Customer_ID              Name                        Email       Phone  \
# 0            1  Deborah Griffith  balljoseph@wright-keith.net  1234567891
# 1            2  Crystal Clements   kimberlybennett@curtis.com  1234567892
#
#               City    Country
# 0  South Craigfort    Denmark
# 1   East Derekberg  Nicaragua

# %%
#Show all customers who ordered more than 1 quantity of a book
df_merged_customers_orders=pd.merge(df_customers, df_orders, on="Customer_ID", how="inner")
df_merged_customers_orders.head(2)
# Out:
#    Customer_ID              Name                       Email       Phone  \
# 0            2  Crystal Clements  kimberlybennett@curtis.com  1234567892
# 1            2  Crystal Clements  kimberlybennett@curtis.com  1234567892
#
#              City    Country  Order_ID  Book_ID Order_Date  Quantity  \
# 0  East Derekberg  Nicaragua       347      118 2023-02-23         3
# 1  East Derekberg  Nicaragua       482      429 2024-08-31         7
#
#    Total_Amount
# 0         16.56
# 1        298.06

# %%
df_merged_customers_orders[df_merged_customers_orders["Quantity"]>1]
# Out:
#      Customer_ID              Name                               Email  \
# 0              2  Crystal Clements          kimberlybennett@curtis.com
# 1              2  Crystal Clements          kimberlybennett@curtis.com
# 2              6   Stephen Vasquez                ricemiguel@yahoo.com
# 5              8   Matthew Johnson           austinkenneth@manning.net
# 6              8   Matthew Johnson           austinkenneth@manning.net
# ..           ...               ...                                 ...
# 495          497       Shane Klein  murphytheodore@rodriguez-lopez.biz
# 496          498   Brianna Fischer            jessicacoleman@yahoo.com
# 497          499    Melissa Curtis           suzannemartinez@gmail.com
# 498          500        James York              maydavid@maldonado.org
# 499          500        James York              maydavid@maldonado.org
#
#           Phone             City        Country  Order_ID  Book_ID Order_Date  \
# ...

# %%
#Retrieve all orders where the total amount exceeds $20
df_orders[df_orders["Total_Amount"]>20]
# Out:
#      Order_ID  Customer_ID  Book_ID Order_Date  Quantity  Total_Amount
# 0           1           84      169 2023-05-26         8        188.56
# 1           2          137      301 2023-01-23        10        216.60
# 2           3          216      261 2024-05-27         6         85.50
# 3           4          433      343 2023-11-25         7        301.21
# 4           5           14      431 2023-07-26         7        136.36
# ..        ...          ...      ...        ...       ...           ...
# 495       496           53      233 2024-09-28         6         62.34
# 496       497          328      272 2023-04-25        10         51.60
# 497       498          152      406 2024-03-10         2         71.58
# 498       499          140       48 2023-08-26         1         24.70
# 499       500          297      137 2024-06-17         5        131.65
#
# [473 rows x 6 columns]

# %%
#List all genres available in the Books table
df_books["Genre"].unique()
# Out:
# array(['Biography', 'Fantasy', 'Non-Fiction', 'Fiction', 'Romance',
#        'Science Fiction', 'Mystery'], dtype=object)

# %%
#Find the book with the lowest stock
df_books.sort_values(by="Stock").head(6)
# Out:
#      Book_ID                                    Title            Author  \
# 59        60              Robust eco-centric capacity       Brian Haney
# 126      127     Business-focused real-time benchmark      David Nelson
# 162      163       Object-based eco-centric challenge  Douglas Mccarthy
# 43        44        Networked systemic implementation        Ryan Frank
# 377      378        Future-proofed heuristic function  Samantha Mcclain
# 136      137  Networked contextually-based encryption    Leslie Montoya
#
#                Genre  Published_Year  Price  Stock
# 59         Biography            1990  35.14      0
# 126  Science Fiction            1997  11.66      0
# 162      Non-Fiction            1905  19.11      0
# 43   Science Fiction            1965  13.55      0
# 377          Romance            1903   6.01      0
# 136        Biography            1942  26.33      1

# %%
#Calculate the total revenue generated from all orders
df_orders["Total_Amount"].sum()
# Out:
# 75628.66

# %% [raw]
# Advance Questions

# %%
#Retrieve the total number of books sold for each genre
df_books.head(2)
# Out:
#    Book_ID                                  Title        Author      Genre  \
# 0        1        Configurable modular throughput  Joseph Crane  Biography
# 1        2  Persevering reciprocal knowledge user   Mario Moore    Fantasy
#
#    Published_Year  Price  Stock
# 0            1949  21.34    100
# 1            1971  35.80     19

# %%
df_orders.head(2)
# Out:
#    Order_ID  Customer_ID  Book_ID Order_Date  Quantity  Total_Amount
# 0         1           84      169 2023-05-26         8        188.56
# 1         2          137      301 2023-01-23        10        216.60

# %%
df_merged_books_orders=pd.merge(df_books, df_orders, on="Book_ID", how="inner")

# %%
df_merged_books_orders.head(2)
# Out:
#    Book_ID                            Title          Author        Genre  \
# 0        1  Configurable modular throughput    Joseph Crane    Biography
# 1        3  Streamlined coherent initiative  Derrick Howard  Non-Fiction
#
#    Published_Year  Price  Stock  Order_ID  Customer_ID Order_Date  Quantity  \
# 0            1949  21.34    100       131           16 2024-05-27         3
# 1            1913  15.75     27        12          454 2024-06-17         2
#
#    Total_Amount
# 0         64.02
# 1         31.50

# %%
df_merged_books_orders.groupby("Genre")["Quantity"].sum()
# Out:
# Genre
# Biography          285
# Fantasy            446
# Fiction            225
# Mystery            504
# Non-Fiction        351
# Romance            439
# Science Fiction    447
# Name: Quantity, dtype: int64

# %%
#Find the average price of books in the "Fantasy" genre
df_genre_fantasy=df_books[df_books["Genre"]=="Fantasy"]

# %%
df_genre_fantasy["Price"].mean()
# Out:
# 25.981690140845068

# %%
#List customers who have placed at least 2 orders
df_merged_customers_orders.head(2)
# Out:
#    Customer_ID              Name                       Email       Phone  \
# 0            2  Crystal Clements  kimberlybennett@curtis.com  1234567892
# 1            2  Crystal Clements  kimberlybennett@curtis.com  1234567892
#
#              City    Country  Order_ID  Book_ID Order_Date  Quantity  \
# 0  East Derekberg  Nicaragua       347      118 2023-02-23         3
# 1  East Derekberg  Nicaragua       482      429 2024-08-31         7
#
#    Total_Amount
# 0         16.56
# 1        298.06

# %%
order_counts=df_merged_customers_orders.groupby("Name").size()

# %%
order_counts[order_counts>=2]
# Out:
# Name
# Alexander Scott    3
# Alyssa Cuevas      3
# Amanda Kramer      2
# Amy Hunt           4
# Andrew Collins     3
#                   ..
# Vanessa Gaines     2
# Victoria Dixon     2
# Vincent Bender     2
# William Cameron    3
# Yvonne Martin      2
# Length: 139, dtype: int64

# %%
#Find the most frequently ordered book
df_merged_books_orders.head(2)
# Out:
#    Book_ID                            Title          Author        Genre  \
# 0        1  Configurable modular throughput    Joseph Crane    Biography
# 1        3  Streamlined coherent initiative  Derrick Howard  Non-Fiction
#
#    Published_Year  Price  Stock  Order_ID  Customer_ID Order_Date  Quantity  \
# 0            1949  21.34    100       131           16 2024-05-27         3
# 1            1913  15.75     27        12          454 2024-06-17         2
#
#    Total_Amount
# 0         64.02
# 1         31.50

# %%
df_merged_books_orders["Title"].value_counts().head(10)
# Out:
# Title
# Devolved zero administration process improvement    4
# Robust tangible hardware                            4
# Pre-emptive intangible adapter                      4
# Advanced responsive extranet                        4
# Realigned multi-tasking installation                4
# Integrated secondary access                         4
# Implemented encompassing conglomeration             4
# Ergonomic zero-defect software                      3
# Multi-channeled mission-critical initiative         3
# Synergized intangible methodology                   3
# Name: count, dtype: int64

# %%
#Show the top 3 most expensive books of 'Fantasy' Genre 
df_genre_fantasy.sort_values(by="Price", ascending=False).head(3)
# Out:
#      Book_ID                              Title             Author    Genre  \
# 239      240      Stand-alone content-based hub         Lisa Ellis  Fantasy
# 461      462  Innovative 3rdgeneration database  Allison Contreras  Fantasy
# 237      238     Optimized even-keeled analyzer    Sherri Griffith  Fantasy
#
#      Published_Year  Price  Stock
# 239            1957  49.90     41
# 461            1988  49.23     62
# 237            1975  48.97     72

# %%
#Retrieve the total quantity of books sold by each author
df_merged_books_orders.head(2)
# Out:
#    Book_ID                            Title          Author        Genre  \
# 0        1  Configurable modular throughput    Joseph Crane    Biography
# 1        3  Streamlined coherent initiative  Derrick Howard  Non-Fiction
#
#    Published_Year  Price  Stock  Order_ID  Customer_ID Order_Date  Quantity  \
# 0            1949  21.34    100       131           16 2024-05-27         3
# 1            1913  15.75     27        12          454 2024-06-17         2
#
#    Total_Amount
# 0         64.02
# 1         31.50

# %%
df_merged_books_orders.groupby("Author")["Quantity"].sum()
# Out:
# Author
# Aaron Hall Jr.       4
# Aaron Rangel         6
# Abigail Madden       5
# Adrian Avery         6
# Alexander Bailey     6
#                     ..
# William Turner       9
# Yolanda Mclean       3
# Zachary Buchanan     1
# Zachary Hayes       15
# Zachary Williams    19
# Name: Quantity, Length: 314, dtype: int64

# %%
#List the cities where customers who spent over $30 are located
df_merged_customers_orders.head(2)
# Out:
#    Customer_ID              Name                       Email       Phone  \
# 0            2  Crystal Clements  kimberlybennett@curtis.com  1234567892
# 1            2  Crystal Clements  kimberlybennett@curtis.com  1234567892
#
#              City    Country  Order_ID  Book_ID Order_Date  Quantity  \
# 0  East Derekberg  Nicaragua       347      118 2023-02-23         3
# 1  East Derekberg  Nicaragua       482      429 2024-08-31         7
#
#    Total_Amount
# 0         16.56
# 1        298.06

# %%
df_merged_customers_orders["City"][df_merged_customers_orders["Total_Amount"]>30]
# Out:
# 1       East Derekberg
# 2         Hamiltonstad
# 5       Kirstenborough
# 6       Kirstenborough
# 7        Lake Benjamin
#             ...
# 495    West Billymouth
# 496         Angelatown
# 497         Ashleyport
# 498        Port Angela
# 499        Port Angela
# Name: City, Length: 443, dtype: object

# %%
#Find the customer who spent the most on orders
df_merged_customers_orders.head(2)
# Out:
#    Customer_ID              Name                       Email       Phone  \
# 0            2  Crystal Clements  kimberlybennett@curtis.com  1234567892
# 1            2  Crystal Clements  kimberlybennett@curtis.com  1234567892
#
#              City    Country  Order_ID  Book_ID Order_Date  Quantity  \
# 0  East Derekberg  Nicaragua       347      118 2023-02-23         3
# 1  East Derekberg  Nicaragua       482      429 2024-08-31         7
#
#    Total_Amount
# 0         16.56
# 1        298.06

# %%
df_merged_customers_orders.groupby('Name')["Total_Amount"].sum().sort_values(ascending=False).head(1)
# Out:
# Name
# Kim Turner    1398.9
# Name: Total_Amount, dtype: float64

# %%
#Calculate the stock remaining after fulfilling all orders
#Mistake in variable: performed inner join function but in variable outer is written
df_merged_books_orders_outer=pd.merge(df_books, df_orders, on="Book_ID", how="left")

# %%
df_merged_books_orders_outer.head(2)
# Out:
#    Book_ID                                  Title        Author      Genre  \
# 0        1        Configurable modular throughput  Joseph Crane  Biography
# 1        2  Persevering reciprocal knowledge user   Mario Moore    Fantasy
#
#    Published_Year  Price  Stock  Order_ID  Customer_ID Order_Date  Quantity  \
# 0            1949  21.34    100     131.0         16.0 2024-05-27       3.0
# 1            1971  35.80     19       NaN          NaN        NaT       NaN
#
#    Total_Amount
# 0         64.02
# 1           NaN

# %%
df_merged_books_orders_outer.fillna(0, inplace=True)
# Out:
# C:\Users\samya\AppData\Local\Temp\ipykernel_8372\1959446853.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   df_merged_books_orders_outer.fillna(0, inplace=True)

# %%
df_merged_books_orders_outer.head(2)
# Out:
#    Book_ID                                  Title        Author      Genre  \
# 0        1        Configurable modular throughput  Joseph Crane  Biography
# 1        2  Persevering reciprocal knowledge user   Mario Moore    Fantasy
#
#    Published_Year  Price  Stock  Order_ID  Customer_ID           Order_Date  \
# 0            1949  21.34    100     131.0         16.0  2024-05-27 00:00:00
# 1            1971  35.80     19       0.0          0.0                    0
#
#    Quantity  Total_Amount
# 0       3.0         64.02
# 1       0.0          0.00

# %%
df_merged_books_orders_outer["Remaining stock"]=df_merged_books_orders_outer["Stock"]-df_merged_books_orders_outer["Quantity"]

# %%
df_remining_stock=df_merged_books_orders_outer[["Book_ID", "Title", "Remaining stock"]]
print (df_remining_stock)
# Out:
#      Book_ID                                         Title  Remaining stock
# 0          1               Configurable modular throughput             97.0
# 1          2         Persevering reciprocal knowledge user             19.0
# 2          3               Streamlined coherent initiative             25.0
# 3          3               Streamlined coherent initiative             24.0
# 4          4                   Customizable 24hour product              8.0
# ..       ...                                           ...              ...
# 678      496                Decentralized radical forecast             96.0
# 679      497             Function-based local installation             30.0
# 680      498                       Secured 24/7 neural-net             22.0
# 681      499  Compatible transitional budgetary management             64.0
# 682      500     Vision-oriented zero tolerance initiative             64.0
#
# [683 rows x 3 columns]
